# %%
from linares_plot import *

# %%
df = pd.read_excel('C:\\Users\\David\\Desktop\\KI_Desktop\\data_reconstructions\\IEM\\IEM_trainT_decoded_angle_shortversion.xlsx')

# %%
def err_deg(a1,ref):
    ### Calculate the error ref-a1 in an efficient way in the circular space
    ### it uses complex numbers!
    ### Input in degrees (0-360)
    a1=np.radians(a1)
    ref=np.radians(ref)
    err = np.angle(np.exp(1j*ref)/np.exp(1j*(a1) ), deg=True) 
    err=round(err, 2)
    return err

# %%
df.head(10)
# Out:
#    Unnamed: 0  decoded_angle  target_centered label_target  corresp_isolated  \
# 0           0     191.899586              180            T             False
# 1           1     167.383801              180          NT1             False
# 2           2     179.330895              180          NT2              True
# 3           3     171.279897              180            T             False
# 4           4     213.186466              180          NT1             False
# 5           5     150.335027              180          NT2              True
# 6           6     193.610179              180            T              True
# 7           7     178.051604              180          NT1             False
# 8           8     178.000366              180          NT2             False
# 9           9     152.943563              180            T              True
#
#    distractor_centered  corresp_isolated_distractor label_distractor  \
# 0                164.0                        False             Dist
# 1                153.7                        False         Dist_NT1
# 2                283.0                         True         Dist_NT2
# 3                161.5                        False             Dist
# 4                153.5                        False         Dist_NT1
# 5                307.0                         True         Dist_NT2
# 6                349.0                         True             Dist
# 7                163.8                        False         Dist_NT1
# 8                150.5                        False         Dist_NT2
# 9                246.0                         True             Dist
#
#    new_index   TR subject brain_region condition
# 0          0  0.0    d001       visual     1_0.2
# 1          0  0.0    d001       visual     1_0.2
# 2          0  0.0    d001       visual     1_0.2
# 3          4  0.0    d001       visual     1_0.2
# 4          4  0.0    d001       visual     1_0.2
# 5          4  0.0    d001       visual     1_0.2
# 6          7  0.0    d001       visual     1_0.2
# 7          7  0.0    d001       visual     1_0.2
# 8          7  0.0    d001       visual     1_0.2
# 9          8  0.0    d001       visual     1_0.2

# %%
error_ = [err_deg(df.iloc[i].decoded_angle, df.iloc[i].target_centered) for i in range(len(df)) ]
distr_distance = [err_deg(df.iloc[i].distractor_centered, df.iloc[i].target_centered) for i in range(len(df)) ]
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in cdouble_scalars
#   import sys

# %%
df['error'] = error_
df['error_abs'] = abs(error_)
df['distractor_distance'] = distr_distance
df['distractor_distance_abs'] = abs(distr_distance)

# %%
df['sign_dist'] = df.distractor_distance<0
df['sign_dist'] = df['sign_dist'].replace([True, False], ['ccw', 'cw'])

# %%
df.head(10)
