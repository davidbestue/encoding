# %%
from linares_plot import *
import sys, os

# %%
path_ = 'C:\\Users\\David\\Documents\\GitHub\\encoding\\scripts\\wm_representation\\functions\\IEM'
sys.path.insert(1, path_)
path_tools = 'C:\\Users\\David\\Documents\\GitHub\\encoding\\scripts\\wm_representation\\functions\\IEM\\tools'
sys.path.insert(1, path_tools)

# %%
from tools import *

# %%
plt.figure(figsize=(9,5))
plt.plot(f(175), linewidth=4, color='darkblue')
plt.plot(f(185), linewidth=4, color='darkred')
plt.xticks(  [0, 9,18,27,35 ], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 35 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f_consecutive_channels.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f2(180), linewidth=4, color='darkblue')
plt.xticks(  [0, 90*2, 180*2, 270*2, 359*2 ], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 359*2 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f2_180.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f2(90), linewidth=4, color='darkblue')
plt.xticks(  [0, 90*2, 180*2, 270*2, 359*2 ], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 359*2 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f2_90.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f2(0), linewidth=4, color='darkblue')
plt.xticks(  [0, 90*2, 180*2, 270*2, 359*2 ], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 359*2 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f2_0.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f2(270), linewidth=4, color='darkblue')
plt.xticks(  [0, 90*2, 180*2, 270*2, 359*2 ], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 359*2 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f2_270.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f(0), linewidth=4, color='darkblue')
plt.xticks(  [0, 9, 18, 27, 35], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 35 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f_0.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f(90), linewidth=4, color='darkblue')
plt.xticks(  [0, 9, 18, 27, 35], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 35 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f_90.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f(180), linewidth=4, color='darkblue')
plt.xticks(  [0, 9, 18, 27, 35], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 35 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f_180.svg', transparent=True) ##to save it transparent

# %%
plt.figure(figsize=(9,5))
plt.plot(f(270), linewidth=4, color='darkblue')
plt.xticks(  [0, 9, 18, 27, 35], [0,90,180,270,359])                                                                       # Aesthetics of the plot
plt.xlim(0, 35 )   
plt.ylim(-0.1,1.01)
plt.yticks([0,0.5,1])
plt.gca().spines['right'].set_visible(False)  # aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
plt.ylabel('channel activity')
plt.xlabel(r'preferred angle ($\circ$) ')
plt.savefig('C:\\Users\\David\\Desktop\\f_270.svg', transparent=True) ##to save it transparent
