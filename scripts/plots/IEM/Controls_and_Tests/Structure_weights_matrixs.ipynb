# %% [markdown]
# Analyzing data coming from the script:
#
# C:\Users\David\Documents\GitHub\encoding\scripts\wm_representation\functions\IEM\Controls\trial_by_trial\structures_weights_matrix.py

# %%
from linares_plot import *
import sys, os
import statsmodels.formula.api as smf
path_tools = 'C:\\Users\\David\\Documents\\GitHub\\encoding\\scripts\\wm_representation\\functions\\IEM\\tools'
sys.path.insert(1, path_tools)
from timecourse import *
from timecourse_c import *
from scipy import stats
from mlxtend.evaluate import permutation_test

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#### Assuiming L1

# %%
path_L1 = 'C:\\Users\\David\\Desktop\\KI_Desktop\\data_reconstructions\\IEM\\wm_l1.xlsx'
xl = pd.ExcelFile(path_L1)
sheet_names = xl.sheet_names

# %%
ROIs_ch_means = []

for i in range(len(sheet_names)):
    WMx = pd.read_excel(path_L1, sheet_name=sheet_names[i])
    mean_ROI = WMx.mean(axis=0)[1:].values
    ROIs_ch_means.append(mean_ROI)

# %%
##Mean Weight of each subject
plt.figure()
for s in [0,4,8,12,16,20]:
    plt.plot(np.array(ROIs_ch_means[s:s+4]).mean(axis=0))
    plt.xticks([0,9,18,27,35], [0,90, 180, 270, 350])
    plt.ylabel('weights')
    plt.xlabel('angle')

plt.show()
    
### Mean Weights
plt.figure()
plt.plot(np.array(ROIs_ch_means).mean(axis=0))
plt.xticks([0,9,18,27,35], [0,90, 180, 270, 350])
plt.ylabel('weights')
plt.xlabel('angle')
plt.show()

# %%
plt.plot(np.array(ROIs_ch_means[4:8]).mean(axis=0))

# %%
np.shape(np.array(ROIs_ch_means))
# Out:
# (24, 36)

# %%
plt.plot(np.array(ROIs_ch_means).mean(axis=0))

# %%
WMx.mean(axis=0).values
# Out:
# array([ 5.28000000e+02, -1.52466367e+01,  5.22356303e+00, -2.25326122e+00,
#         1.06005284e+00, -1.01066906e-01,  4.97772949e-01, -1.27276159e+00,
#         5.61360749e+00, -2.11926108e+01,  3.84127673e+01, -4.96899327e+00,
#        -8.60478679e-01,  2.42820759e+00, -3.04209776e+00,  4.34435449e+00,
#        -6.24831284e+00,  1.26956771e+01, -3.52705056e+01,  9.33757183e+00,
#        -4.86749359e+00,  3.60653166e+00, -2.61187698e+00,  2.33385848e+00,
#        -3.00473784e+00,  4.56487183e+00, -4.87702806e+00,  1.42948356e+01,
#        -6.82272957e+02,  7.29528889e+01, -1.46904635e+01,  4.46083938e+00,
#        -1.09942072e+00, -1.22449101e-02,  1.23987264e+00, -1.39585689e+00,
#         8.13662337e+00])

# %%
plt.plot(WMx.mean(axis=0)[1:].values)
